# %%
import imp
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit

# %matplotlib inline
# Out:
# C:\Users\arslan\AppData\Local\Temp\ipykernel_1100\186090197.py:1: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
marks = pd.read_csv('exams.csv', parse_dates=['gender'])

# %%
marks.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68

# %%
marks['math score'].mean()
# Out:
# 66.396

# %%
marks['math score'].plot(kind='kde', figsize=(14,6))
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
marks['math score'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
marks['reading score'].mean()
# Out:
# 69.002

# %%
marks['reading score'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
marks['reading score'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
marks['gender'].value_counts().head(1)
# Out:
# male    517
# Name: gender, dtype: int64

# %%
marks['gender'].value_counts()
# Out:
# male      517
# female    483
# Name: gender, dtype: int64

# %%
marks['gender'].value_counts().plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
marks['parental level of education'].unique()
# Out:
# array(['high school', 'some high school', 'some college',
#        "associate's degree", "bachelor's degree", "master's degree"],
#       dtype=object)

# %%
marks['parental level of education'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
marks.plot(kind='scatter', x='math score', y='reading score', figsize=(6,6))
# Out:
# <AxesSubplot: xlabel='math score', ylabel='reading score'>

# %%
marks.plot(kind='scatter', x='reading score', y='writing score', figsize=(6,6))
# Out:
# <AxesSubplot: xlabel='reading score', ylabel='writing score'>

# %%
marks[['parental level of education', 'math score']].boxplot(by='parental level of education', figsize=(10,6))
# Out:
# <AxesSubplot: title={'center': 'math score'}, xlabel='[parental level of education]'>

# %%
marks[['lunch', 'math score']].boxplot(by='lunch', figsize=(10,6))
# Out:
# <AxesSubplot: title={'center': 'math score'}, xlabel='[lunch]'>

# %%
marks['parental level of education'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot: ylabel='parental level of education'>

# %%
marks['gender'].value_counts()
# Out:
# male      517
# female    483
# Name: gender, dtype: int64

# %%
marks['gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >
